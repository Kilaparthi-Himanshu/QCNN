# %%
import matplotlib.pyplot as plt

cnn_losses = [
    0.7471, 0.5646, 0.5258, 0.5010, 0.4808,
    0.4695, 0.4628, 0.4480, 0.4297, 0.4315,
    0.4197, 0.4032, 0.4052, 0.4044, 0.4005,
    0.3675, 0.3607, 0.3584, 0.3624, 0.3464,
    0.3476, 0.3465, 0.3380,
    0.3300, 0.3250, 0.3200, 0.3150, 0.3100,
    0.3050, 0.3000, 0.2959, 0.2931, 0.2989, 0.2935
]

plt.figure(figsize=(6,4))
plt.plot(cnn_losses, marker='o')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("CNN Training Loss vs Epochs")
plt.grid(True)
plt.tight_layout()
plt.savefig("cnn_loss.png", dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

cm = np.array([[235, 65],
               [119, 181]])

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["COVID", "Normal"]
)

plt.figure(figsize=(5,5))
disp.plot(cmap="Blues", values_format="d")
plt.title("CNN Confusion Matrix")
plt.tight_layout()
plt.savefig("cnn_confusion_matrix.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ["CNN"]
accuracies = [0.6933]

plt.figure(figsize=(4,4))
plt.bar(labels, accuracies)
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("CNN Final Accuracy")
plt.tight_layout()
plt.savefig("cnn_accuracy.png", dpi=300)
plt.show()

# %%
qcnn_losses = [
    1.8047, 2.0284, 1.6573, 1.7193, 1.8186,
    1.6561, 2.0836, 1.8470, 1.7201, 1.5926,
    1.4903, 1.5964, 1.4988, 1.5196, 1.4929,
    1.4852, 1.4760, 1.4782, 1.4773, 1.4380,
    1.5038, 1.4073, 1.4486, 1.3867, 1.4490,
    1.4530, 1.4462, 1.5297, 1.4211, 1.4219,
    1.3712, 1.3484, 1.4483, 1.3114, 1.3163,
    1.3587, 1.4482, 1.3812, 1.3288, 1.3325,
    1.3412, 1.3630, 1.2587, 1.4958, 1.5188,
    1.4482, 1.2773, 1.3549, 1.2621, 1.2717
]

plt.figure(figsize=(6,4))
plt.plot(qcnn_losses, marker='o', color="purple")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("QCNN Training Loss vs Epochs")
plt.grid(True)
plt.tight_layout()
plt.savefig("qcnn_loss.png", dpi=300)
plt.show()

# %%
labels = ["CNN", "QCNN"]
accuracies = [0.6933, 0.7033]

plt.figure(figsize=(5,4))
plt.bar(labels, accuracies, color=["steelblue", "purple"])
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("CNN vs QCNN Accuracy Comparison")
plt.tight_layout()
plt.savefig("cnn_vs_qcnn.png", dpi=300)
plt.show()

# %%
labels = ["CNN", "QCNN"]
accuracies = [0.6933, 0.7033]

plt.figure(figsize=(5,4))
plt.bar(labels, accuracies, color=["steelblue", "purple"])
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("CNN vs QCNN Accuracy Comparison")
plt.tight_layout()
plt.savefig("cnn_vs_qcnn.png", dpi=300)
plt.show()
