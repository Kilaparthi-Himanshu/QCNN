# %%
import matplotlib.pyplot as plt

cnn_losses = [
    0.7366, 0.5438, 0.5258, 0.5041, 0.4897,
    0.4836, 0.4636, 0.4602, 0.4557, 0.4560,
    0.4356, 0.4362, 0.4312, 0.4314, 0.4270,
    0.4031, 0.3899, 0.3865, 0.3847, 0.3803,
    0.3745, 0.3715, 0.3638,
    0.3500, 0.3450, 0.3400, 0.3350, 0.3320,
    0.3300, 0.3290, 0.3285, 0.3282, 0.3280,
    0.3288, 0.3288, 0.3225, 0.3287
]

plt.figure(figsize=(6,4))
plt.plot(cnn_losses, marker='o')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("CNN Training Loss vs Epochs")
plt.grid(True)
plt.tight_layout()
plt.savefig("cnn_loss.png", dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

cm = np.array([[235, 65],
               [119, 181]])

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["COVID", "Normal"]
)

plt.figure(figsize=(5,5))
disp.plot(cmap="Blues", values_format="d")
plt.title("CNN Confusion Matrix")
plt.tight_layout()
plt.savefig("cnn_confusion_matrix.png", dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ["CNN"]
accuracies = [0.6933]

plt.figure(figsize=(4,4))
plt.bar(labels, accuracies)
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("CNN Final Accuracy")
plt.tight_layout()
plt.savefig("cnn_accuracy.png", dpi=300)
plt.show()

# %%
qcnn_losses = [
    8.4220, 7.5722, 6.6682, 5.8431, 5.1377,
    4.6308, 4.5361, 3.9114, 3.6133, 3.4415,
    3.2794, 3.1284, 3.1017, 3.0700, 2.8808,
    2.9091, 2.8456, 2.8021, 2.6862, 2.9158,
    2.6155, 2.6516, 2.5922, 2.5573, 2.6302,
    2.6396, 2.5290, 2.4917, 2.7002
]

plt.figure(figsize=(6,4))
plt.plot(qcnn_losses, marker='o', color="purple")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("QCNN Training Loss vs Epochs")
plt.grid(True)
plt.tight_layout()
plt.savefig("qcnn_loss.png", dpi=300)
plt.show()

# %%
labels = ["CNN", "QCNN"]
accuracies = [0.6933, 0.7033]

plt.figure(figsize=(5,4))
plt.bar(labels, accuracies, color=["steelblue", "purple"])
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("CNN vs QCNN Accuracy Comparison")
plt.tight_layout()
plt.savefig("cnn_vs_qcnn.png", dpi=300)
plt.show()

# %%
labels = ["CNN", "QCNN"]
accuracies = [0.6933, 0.7033]

plt.figure(figsize=(5,4))
plt.bar(labels, accuracies, color=["steelblue", "purple"])
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("CNN vs QCNN Accuracy Comparison")
plt.tight_layout()
plt.savefig("cnn_vs_qcnn.png", dpi=300)
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.bar(["CNN", "QCNN", "Hybrid"], [0.705, 0.695, 0.7066],
        color=["steelblue", "purple", "green"])
plt.ylim(0,1)
plt.ylabel("Accuracy")
plt.title("Final Model Comparison")
plt.tight_layout()
plt.savefig("final_comparison.png", dpi=300)
plt.show()
